# %% [markdown]
# <a href="https://colab.research.google.com/github/ygm0516/data_analysis/blob/main/data_analysis_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 서울시 자치구별 CCTV 현황 데이터 분석

# %% [markdown]
# # 1. 서울시 자치구별 CCTV 현황 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Colab에서는 파일의경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
#예) CCTV_Seoul = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/서울시 CCTV 설치운영 현황(자치구)-연도별.csv',encoding='cp949')
CCTV_Seoul = pd.read_csv('/content/drive/MyDrive/대학교파일/4학년1학기/데이터분석/11주차 데이터 분석/서울시 CCTV 설치운영 현황(자치구)-연도별.csv',encoding='cp949')
CCTV_Seoul
# Out:
#       구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0      계  75431      5901   1619   2228   4597   4368   6742   8300  10100
# 1    종로구   1729       216      7     10    582    210    150      1    259
# 2     중구   2001        16      6    199     90    125    218    333    462
# 3    용산구   2383        31      3     71    234    125    221    298    351
# 4    성동구   3515       487     26    122    207    112    335    309    790
# 5    광진구   2556        11     24     57    100    187     98     52    675
# 6   동대문구   2315       960    130    146     60     29    111    233    136
# 7    중랑구   3285       298     21     23    253     88    138    159    152
# 8    성북구   3754        42     41     87    174    230    323    587    461
# 9    강북구   2462         0      0      0     55     85    130    311     34
# 10   도봉구   1356         0     49     29     96    181     79    159    134
# 11   노원구   2282         0      0     90    105    109    605    405    256
# 12   은평구   3660        14      0      3     44    332    329    555    403
# 13  서대문구   2939       386    179    233    214    114    109    277    415
# 14   마포구   2401       270     66     93     77     61    162    350    358
# 15   양천구   3307      1217    282    175    201    173    193    351    120
# 16   강서구   2437        26     29    129    106    213    188    168    506
# 17   구로구   4075       643    209    216    349    187    268    326    540
# 18   금천구   2365         0      0      0    178     80    361    133    196
# 19  영등포구   3773       450    122    136    238    123    209    248    311
# 20   동작구   2262       165     73     93     29    503    130    254    278
# 21   관악구   4909       320    120     84    431    441    608    620    684
# 22   서초구   3730         0    117     72     93     71    563    516   1061
# 23   강남구   6645        62     61     72    368    455    845   1307   1004
# 24   송파구   2743        64      9     61     86     85    215    146    241
# 25   강동구   2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 0    9687  11657  10232
# 1      85      9    200
# 2     228    194    130
# 3     125    307    617
# 4     409    262    456
# 5     465    712    175
# 6     197    209    104
# 7     173   1050    930
# 8     860    716    233
# 9     385    976    486
# 10    223    214    192
# 11    201    240    271
# 12    635   1057    288
# 13    246    328    438
# 14    340    384    240
# 15    142    255    198
# 16    259    457    356
# 17    488    434    415
# 18    540    369    508
# 19    658     65   1213
# 20    255    242    240
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %% [markdown]
# # 2. CCTV 현황 데이터 살펴보기

# %%
#데이터의 행x열 개수,컬럼,인덱스 정보 보기

CCTV_Seoul.shape
# Out:
# (26, 13)

# %%
#데이터의 위에서 5행 보기
CCTV_Seoul.head(5)
# Out:
#     구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228   4597   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#데이터의 아래에서 5행 보기
CCTV_Seoul.tail(5)
# Out:
#      구분    총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 21  관악구  4909       320    120     84    431    441    608    620    684
# 22  서초구  3730         0    117     72     93     71    563    516   1061
# 23  강남구  6645        62     61     72    368    455    845   1307   1004
# 24  송파구  2743        64      9     61     86     85    215    146    241
# 25  강동구  2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %%
#데이터의 통계정보 보기
CCTV_Seoul.describe()
# Out:
#                  총계     2011년 이전        2011년        2012년        2013년  \
# count     26.000000    26.000000    26.000000    26.000000    26.000000
# mean    5802.384615   453.923077   124.538462   171.384615   353.615385
# std    14243.300744  1153.586266   313.384522   424.613337   875.485606
# min     1356.000000     0.000000     0.000000     0.000000    29.000000
# 25%     2369.500000    14.500000     7.500000    36.000000    90.750000
# 50%     2649.500000   114.500000    43.000000    85.500000   176.000000
# 75%     3712.500000   369.500000   119.250000   134.250000   237.000000
# max    75431.000000  5901.000000  1619.000000  2228.000000  4597.000000
#
#              2014년        2015년        2016년         2017년        2018년  \
# count    26.000000    26.000000    26.000000     26.000000    26.000000
# mean    336.000000   518.615385   638.461538    776.923077   745.153846
# std     832.063988  1283.423424  1582.773167   1919.477344  1835.587224
# min      29.000000    79.000000     1.000000     34.000000    85.000000
# 25%      85.750000   141.000000   176.500000    244.750000   224.250000
# 50%     125.000000   212.000000   303.500000    354.500000   381.000000
# 75%     212.250000   333.500000   391.500000    531.500000   541.500000
# max    4368.000000  6742.000000  8300.000000  10100.000000  9687.000000
#
#               2019년         2020년
# count     26.000000     26.000000
# mean     896.692308    787.076923
# std     2216.506346   1945.202487
# min        9.000000    104.000000
# 25%      245.250000    227.750000
# 50%      365.000000    343.500000
# 75%      715.000000    502.500000
# max    11657.000000  10232.000000

# %%
#데이터의 타입, 아이템 수, 누락데이터 등 보기
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     int64
#  2   2011년 이전  26 non-null     int64
#  3   2011년     26 non-null     int64
#  4   2012년     26 non-null     int64
#  5   2013년     26 non-null     int64
#  6   2014년     26 non-null     int64
#  7   2015년     26 non-null     int64
#  8   2016년     26 non-null     int64
#  9   2017년     26 non-null     int64
#  10  2018년     26 non-null     int64
#  11  2019년     26 non-null     int64
#  12  2020년     26 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# # 3. CCTV 현황 데이터 정리하기

# %%
#CCTV_Seoul 데이터의 열이름을 '구분' -> '구별'로 변경 (columns={'구분' : '구별'})

CCTV_Seoul.rename(columns={'구분':'구별'},inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228   4597   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#다른 데이터들과 년도를 동일하게 맞추기 위해 '2020년' 열 삭제 (columns='2020년',axis=1)

CCTV_Seoul.drop(columns='2020년',axis=1,inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228   4597   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년
# 0   9687  11657
# 1     85      9
# 2    228    194
# 3    125    307
# 4    409    262

# %%
#'2017년 이전' 열 추가
CCTV_Seoul['2017년 이전']=CCTV_Seoul['2011년 이전']+CCTV_Seoul['2011년']+CCTV_Seoul['2012년']+CCTV_Seoul['2013년']+CCTV_Seoul['2014년']+CCTV_Seoul['2015년']+CCTV_Seoul['2016년']
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228   4597   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2017년 이전
# 0   9687  11657     33755
# 1     85      9      1176
# 2    228    194       987
# 3    125    307       983
# 4    409    262      1598

# %%
#불필요한 년도의 열('2011년 이전', '2011년', '2012년', '2013년', '2014년','2015년','2016년') 삭제
CCTV_Seoul.drop(columns=['2011년 이전', '2011년', '2012년', '2013년', '2014년','2015년','2016년'], axis=1,inplace=True)

CCTV_Seoul.head()
# Out:
#     구별     총계  2017년  2018년  2019년  2017년 이전
# 0    계  75431  10100   9687  11657     33755
# 1  종로구   1729    259     85      9      1176
# 2   중구   2001    462    228    194       987
# 3  용산구   2383    351    125    307       983
# 4  성동구   3515    790    409    262      1598

# %%
CCTV_Seoul.head()
# Out:
#     구별     총계  2017년  2018년  2019년  2017년 이전
# 0    계  75431  10100   9687  11657     33755
# 1  종로구   1729    259     85      9      1176
# 2   중구   2001    462    228    194       987
# 3  용산구   2383    351    125    307       983
# 4  성동구   3515    790    409    262      1598

# %%
#불필요한 행(index=0, axis=0) 삭제

CCTV_Seoul.drop(index=0, axis=0,inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 1  종로구  1729    259     85      9      1176
# 2   중구  2001    462    228    194       987
# 3  용산구  2383    351    125    307       983
# 4  성동구  3515    790    409    262      1598
# 5  광진구  2556    675    465    712       529

# %%
#drop = True 기존의 인덱스는 버리고 새로 설정
CCTV_Seoul.reset_index(drop=True, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 0  종로구  1729    259     85      9      1176
# 1   중구  2001    462    228    194       987
# 2  용산구  2383    351    125    307       983
# 3  성동구  3515    790    409    262      1598
# 4  광진구  2556    675    465    712       529

# %% [markdown]
# # 4. CCTV 현황데이터 자세히 보기

# %% [markdown]
# ### 4-1. CCTV의 전체 개수가 가장 적은/가장 많은 상위 5개 구는 어디일까?

# %%
#데이터 '총계'열을 기준으로 오름차순 정렬하기 (by='총계', ascending = True)

CCTV_Seoul.sort_values(by='총계', ascending = True)
# Out:
#       구별    총계  2017년  2018년  2019년  2017년 이전
# 9    도봉구  1356    134    223    214       593
# 0    종로구  1729    259     85      9      1176
# 1     중구  2001    462    228    194       987
# 19   동작구  2262    278    255    242      1247
# 10   노원구  2282    256    201    240      1314
# 5   동대문구  2315    136    197    209      1669
# 17   금천구  2365    196    540    369       752
# 2    용산구  2383    351    125    307       983
# 13   마포구  2401    358    340    384      1079
# 15   강서구  2437    506    259    457       859
# 8    강북구  2462     34    385    976       581
# 24   강동구  2547    273    377    356       927
# 4    광진구  2556    675    465    712       529
# 23   송파구  2743    241    542   1068       666
# 12  서대문구  2939    415    246    328      1512
# 6    중랑구  3285    152    173   1050       980
# 14   양천구  3307    120    142    255      2592
# 3    성동구  3515    790    409    262      1598
# 11   은평구  3660    403    635   1057      1277
# 21   서초구  3730   1061    436    361      1432
# 7    성북구  3754    461    860    716      1484
# 18  영등포구  3773    311    658     65      1526
# 16   구로구  4075    540    488    434      2198
# 20   관악구  4909    684    674    596      2624
# 22   강남구  6645   1004    744    796      3170

# %%
#데이터 '총계'열을 기준으로 내림차순 정렬하기 (by='총계', ascending = False)

CCTV_Seoul.sort_values(by='총계', ascending = False)
# Out:
#       구별    총계  2017년  2018년  2019년  2017년 이전
# 22   강남구  6645   1004    744    796      3170
# 20   관악구  4909    684    674    596      2624
# 16   구로구  4075    540    488    434      2198
# 18  영등포구  3773    311    658     65      1526
# 7    성북구  3754    461    860    716      1484
# 21   서초구  3730   1061    436    361      1432
# 11   은평구  3660    403    635   1057      1277
# 3    성동구  3515    790    409    262      1598
# 14   양천구  3307    120    142    255      2592
# 6    중랑구  3285    152    173   1050       980
# 12  서대문구  2939    415    246    328      1512
# 23   송파구  2743    241    542   1068       666
# 4    광진구  2556    675    465    712       529
# 24   강동구  2547    273    377    356       927
# 8    강북구  2462     34    385    976       581
# 15   강서구  2437    506    259    457       859
# 13   마포구  2401    358    340    384      1079
# 2    용산구  2383    351    125    307       983
# 17   금천구  2365    196    540    369       752
# 5   동대문구  2315    136    197    209      1669
# 10   노원구  2282    256    201    240      1314
# 19   동작구  2262    278    255    242      1247
# 1     중구  2001    462    228    194       987
# 0    종로구  1729    259     85      9      1176
# 9    도봉구  1356    134    223    214       593

# %% [markdown]
# ### 4-2. 최근 3년간 CCTV 증가율을 계산하여 '최근증가율' 을 알아보자.

# %%
#최근 3년간 CCTV 수를 더하고 2017년 이전 CCTV수로 나눠서 최근 3년간 CCTV 증가율 계산

CCTV_Seoul['최근증가율']=(CCTV_Seoul['2019년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2017년']) / CCTV_Seoul['2017년 이전']  * 100
CCTV_Seoul.rename(columns={'총계':'CCTV수'},inplace=True)

CCTV_Seoul.head()
# Out:
#     구별  CCTV수  2017년  2018년  2019년  2017년 이전       최근증가율
# 0  종로구   1729    259     85      9      1176   30.017007
# 1   중구   2001    462    228    194       987   89.564336
# 2  용산구   2383    351    125    307       983   79.654120
# 3  성동구   3515    790    409    262      1598   91.426783
# 4  광진구   2556    675    465    712       529  350.094518

# %% [markdown]
# ### 4-3. '최근증가율' 이 가장 높은 상위 5개구는 어디일까?

# %%
#'최근증가율'로 내림차순 정렬
CCTV_Seoul.sort_values(by='최근증가율', ascending = False)
# Out:
#       구별  CCTV수  2017년  2018년  2019년  2017년 이전       최근증가율
# 4    광진구   2556    675    465    712       529  350.094518
# 23   송파구   2743    241    542   1068       666  277.927928
# 8    강북구   2462     34    385    976       581  240.103270
# 11   은평구   3660    403    635   1057      1277  164.056382
# 17   금천구   2365    196    540    369       752  146.941489
# 15   강서구   2437    506    259    457       859  142.258440
# 6    중랑구   3285    152    173   1050       980  140.306122
# 7    성북구   3754    461    860    716      1484  137.264151
# 21   서초구   3730   1061    436    361      1432  129.748603
# 24   강동구   2547    273    377    356       927  108.522114
# 13   마포구   2401    358    340    384      1079  100.278035
# 9    도봉구   1356    134    223    214       593   96.290051
# 3    성동구   3515    790    409    262      1598   91.426783
# 1     중구   2001    462    228    194       987   89.564336
# 22   강남구   6645   1004    744    796      3170   80.252366
# 2    용산구   2383    351    125    307       983   79.654120
# 20   관악구   4909    684    674    596      2624   74.466463
# 18  영등포구   3773    311    658     65      1526   67.758847
# 16   구로구   4075    540    488    434      2198   66.515014
# 12  서대문구   2939    415    246    328      1512   65.410053
# 19   동작구   2262    278    255    242      1247   62.149158
# 10   노원구   2282    256    201    240      1314   53.044140
# 5   동대문구   2315    136    197    209      1669   32.474536
# 0    종로구   1729    259     85      9      1176   30.017007
# 14   양천구   3307    120    142    255      2592   19.945988

# %% [markdown]
# # 5. 서울시 인구현황 데이터 읽어오기

# %%
# Colab에서는 파일의 경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
# 예) pop_Seoul = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/행정구역_시군구_별__성별_인구수_서울.xlsx')
import pandas as pd
#header= 1 옵션은 액셀에서 두번째 줄부터 읽어옴 (숫자는 0부터 시작)
pop_Seoul = pd.read_excel('/content/drive/MyDrive/대학교파일/4학년1학기/데이터분석/11주차 데이터 분석/행정구역_시군구_별__성별_인구수_서울.xlsx')

pop_Seoul.head()
# Out:
#    행정구역(시군구)별  2019. 12 2019. 12.1 2019. 12.2
# 0  행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1           계   9729107    4744059    4985048
# 2         종로구    151290      73746      77544
# 3          중구    126171      61910      64261
# 4         용산구    228670     110356     118314

# %%
#데이터의 행,열 개수,컬럼,인덱스 정보 보기
print(pop_Seoul.shape)
print(pop_Seoul.index)
# Out:
# (27, 4)
# RangeIndex(start=0, stop=27, step=1)

# %% [markdown]
# # 6. 인구 현황 데이터 정리하기

# %%
#컬럼 이름 변경
pop_Seoul.rename(columns={'행정구역(시군구)별':'구별'}, inplace=True)
pop_Seoul.rename(columns={'2019. 12':'총인구수'}, inplace=True)
pop_Seoul.rename(columns={'2019. 12.1':'남자인구수'}, inplace=True)
pop_Seoul.rename(columns={'2019. 12.2':'여자인구수'}, inplace=True)
pop_Seoul.head()
# Out:
#            구별      총인구수      남자인구수      여자인구수
# 0  행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1           계   9729107    4744059    4985048
# 2         종로구    151290      73746      77544
# 3          중구    126171      61910      64261
# 4         용산구    228670     110356     118314

# %%
#불필요한 행 삭제, 0번 인덱스 줄 삭제
pop_Seoul.drop (index=0, axis=0, inplace=True)
pop_Seoul.head()
# Out:
#     구별     총인구수    남자인구수    여자인구수
# 1    계  9729107  4744059  4985048
# 2  종로구   151290    73746    77544
# 3   중구   126171    61910    64261
# 4  용산구   228670   110356   118314
# 5  성동구   300889   147273   153616

# %%
#인덱스 새로 설정
pop_Seoul.reset_index(drop=True, inplace=True)
pop_Seoul.head()
# Out:
#     구별     총인구수    남자인구수    여자인구수
# 0    계  9729107  4744059  4985048
# 1  종로구   151290    73746    77544
# 2   중구   126171    61910    64261
# 3  용산구   228670   110356   118314
# 4  성동구   300889   147273   153616

# %% [markdown]
# # 7. 인구현황 데이터 자세히 보기

# %% [markdown]
# ### 7-1. 인구수가 가장 높은 상위 5개 구는 어디일까?

# %%
#'인구수'로 내림차순 정렬
pop_Seoul.sort_values(by='총인구수', ascending=False)
# Out:
#       구별     총인구수    남자인구수    여자인구수
# 0      계  9729107  4744059  4985048
# 24   송파구   675961   327164   348797
# 16   강서구   591796   286563   305233
# 23   강남구   545169   260806   284363
# 11   노원구   532905   257923   274982
# 21   관악구   500094   251009   249085
# 12   은평구   480032   231528   248504
# 15   양천구   458165   225186   232979
# 8    성북구   442650   214437   228213
# 25   강동구   436067   215335   220732
# 22   서초구   430826   206039   224787
# 17   구로구   406664   200987   205677
# 7    중랑구   397015   196959   200056
# 20   동작구   395963   191976   203987
# 14   마포구   374035   176891   197144
# 19  영등포구   367678   182438   185240
# 5    광진구   351350   170262   181088
# 6   동대문구   346194   172113   174081
# 10   도봉구   333362   163051   170311
# 9    강북구   313954   153235   160719
# 13  서대문구   309397   148663   160734
# 4    성동구   300889   147273   153616
# 18   금천구   232810   118209   114601
# 3    용산구   228670   110356   118314
# 1    종로구   151290    73746    77544
# 2     중구   126171    61910    64261

# %% [markdown]
# ###  7-2. 여성인구와 남성인구 비율을 알아보자

# %%
pop_Seoul['여성비율']=(pop_Seoul['여자인구수']/pop_Seoul['총인구수']*100).astype(int)
pop_Seoul['남성비율']=(pop_Seoul['남자인구수']/pop_Seoul['총인구수']*100).astype(int)

pop_Seoul.head()
# Out:
#     구별     총인구수    남자인구수    여자인구수  여성비율  남성비율
# 0    계  9729107  4744059  4985048    51    48
# 1  종로구   151290    73746    77544    51    48
# 2   중구   126171    61910    64261    50    49
# 3  용산구   228670   110356   118314    51    48
# 4  성동구   300889   147273   153616    51    48

# %% [markdown]
# ### 7-3. 여성비율이 가장 높은 상위 5개 구는 어디일까?

# %%
#'여성비율'로 내림차순 정렬
pop_Seoul.sort_values(by='여성비율', ascending=False).head(5)
# Out:
#      구별     총인구수    남자인구수    여자인구수  여성비율  남성비율
# 23  강남구   545169   260806   284363    52    47
# 22  서초구   430826   206039   224787    52    47
# 14  마포구   374035   176891   197144    52    47
# 0     계  9729107  4744059  4985048    51    48
# 11  노원구   532905   257923   274982    51    48

# %% [markdown]
# ### 7-4. 남성비율이 가장 높은 상위 5개 구는 어디일까?

# %%
#'남성비율'로 내림차순 정렬
pop_Seoul.sort_values(by='남성비율', ascending=False).head(5)
# Out:
#       구별    총인구수   남자인구수   여자인구수  여성비율  남성비율
# 21   관악구  500094  251009  249085    49    50
# 18   금천구  232810  118209  114601    49    50
# 25   강동구  436067  215335  220732    50    49
# 2     중구  126171   61910   64261    50    49
# 6   동대문구  346194  172113  174081    50    49

# %% [markdown]
# # 8. 데이터 합치기

# %% [markdown]
# ### 8-1. 인구 대비 CCTV 현황을 확인해 보자

# %%
# 두 데이터 합치기 (병합기준 열을 '구별'로 병합, on='구별')
data_result=pd.merge(pop_Seoul,CCTV_Seoul, on='구별')

data_result.head()
# Out:
#     구별    총인구수   남자인구수   여자인구수  여성비율  남성비율  CCTV수  2017년  2018년  2019년  \
# 0  종로구  151290   73746   77544    51    48   1729    259     85      9
# 1   중구  126171   61910   64261    50    49   2001    462    228    194
# 2  용산구  228670  110356  118314    51    48   2383    351    125    307
# 3  성동구  300889  147273  153616    51    48   3515    790    409    262
# 4  광진구  351350  170262  181088    51    48   2556    675    465    712
#
#    2017년 이전       최근증가율
# 0      1176   30.017007
# 1       987   89.564336
# 2       983   79.654120
# 3      1598   91.426783
# 4       529  350.094518

# %% [markdown]
# ### 8-2. 인덱스 이름을 구이름으로 바꿔보자

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        총인구수   남자인구수   여자인구수  여성비율  남성비율  CCTV수  2017년  2018년  2019년  2017년 이전  \
# 구별
# 종로구  151290   73746   77544    51    48   1729    259     85      9      1176
# 중구   126171   61910   64261    50    49   2001    462    228    194       987
# 용산구  228670  110356  118314    51    48   2383    351    125    307       983
# 성동구  300889  147273  153616    51    48   3515    790    409    262      1598
# 광진구  351350  170262  181088    51    48   2556    675    465    712       529
#
#           최근증가율
# 구별
# 종로구   30.017007
# 중구    89.564336
# 용산구   79.654120
# 성동구   91.426783
# 광진구  350.094518

# %%
#합친 데이터 엑셀파일로 저장하기
# Colab에서는 파일의 경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
# 예) excel_writer = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/CCTV_pop.xlsx')

excel_writer = pd.ExcelWriter('/content/drive/MyDrive/대학교파일/4학년1학기/데이터분석/11주차 데이터 분석/CCTV_pop.xlsx')
data_result.to_excel(excel_writer, index=True)
excel_writer.close()

# %%
print(data_result.dtypes)
# Out:
# 총인구수         object
# 남자인구수        object
# 여자인구수        object
# 여성비율          int64
# 남성비율          int64
# CCTV수         int64
# 2017년         int64
# 2018년         int64
# 2019년         int64
# 2017년 이전      int64
# 최근증가율       float64
# dtype: object

# %% [markdown]
# # 9. 서울시 자치구별 CCTV 현황 분석하기

# %% [markdown]
# ### 9-1. CCTV 수에 가장 영향을 미치는 항목은 무엇일까?

# %%
import numpy as np

# 두 항목간의 상관계수 대각선을 제외하고 상관계수 절대값이 1에 가까울 수록 높은 상관 관계

np.corrcoef(data_result['여성비율'],data_result['CCTV수'])
# Out:
# array([[1.        , 0.04961905],
#        [0.04961905, 1.        ]])

# %% [markdown]
# ### 9-2. CCTV 수에 가장 영향을 미치는 항목의 수가 가장 큰 구는 CCTV 수도 가장 큰가?

# %%
#'총인구수'로 내림차순 정렬

data_result.sort_values(by='총인구수', ascending = True)
# Out:
#         총인구수   남자인구수   여자인구수  여성비율  남성비율  CCTV수  2017년  2018년  2019년  \
# 구별
# 중구    126171   61910   64261    50    49   2001    462    228    194
# 종로구   151290   73746   77544    51    48   1729    259     85      9
# 용산구   228670  110356  118314    51    48   2383    351    125    307
# 금천구   232810  118209  114601    49    50   2365    196    540    369
# 성동구   300889  147273  153616    51    48   3515    790    409    262
# 서대문구  309397  148663  160734    51    48   2939    415    246    328
# 강북구   313954  153235  160719    51    48   2462     34    385    976
# 도봉구   333362  163051  170311    51    48   1356    134    223    214
# 동대문구  346194  172113  174081    50    49   2315    136    197    209
# 광진구   351350  170262  181088    51    48   2556    675    465    712
# 영등포구  367678  182438  185240    50    49   3773    311    658     65
# 마포구   374035  176891  197144    52    47   2401    358    340    384
# 동작구   395963  191976  203987    51    48   2262    278    255    242
# 중랑구   397015  196959  200056    50    49   3285    152    173   1050
# 구로구   406664  200987  205677    50    49   4075    540    488    434
# 서초구   430826  206039  224787    52    47   3730   1061    436    361
# 강동구   436067  215335  220732    50    49   2547    273    377    356
# 성북구   442650  214437  228213    51    48   3754    461    860    716
# 양천구   458165  225186  232979    50    49   3307    120    142    255
# 은평구   480032  231528  248504    51    48   3660    403    635   1057
# 관악구   500094  251009  249085    49    50   4909    684    674    596
# 노원구   532905  257923  274982    51    48   2282    256    201    240
# 강남구   545169  260806  284363    52    47   6645   1004    744    796
# 강서구   591796  286563  305233    51    48   2437    506    259    457
# 송파구   675961  327164  348797    51    48   2743    241    542   1068
#
#       2017년 이전       최근증가율
# 구별
# 중구         987   89.564336
# 종로구       1176   30.017007
# 용산구        983   79.654120
# 금천구        752  146.941489
# 성동구       1598   91.426783
# 서대문구      1512   65.410053
# 강북구        581  240.103270
# 도봉구        593   96.290051
# 동대문구      1669   32.474536
# 광진구        529  350.094518
# 영등포구      1526   67.758847
# 마포구       1079  100.278035
# 동작구       1247   62.149158
# 중랑구        980  140.306122
# 구로구       2198   66.515014
# 서초구       1432  129.748603
# 강동구        927  108.522114
# 성북구       1484  137.264151
# 양천구       2592   19.945988
# 은평구       1277  164.056382
# 관악구       2624   74.466463
# 노원구       1314   53.044140
# 강남구       3170   80.252366
# 강서구        859  142.258440
# 송파구        666  277.927928

# %%
#'CCTV수'로 내림차순 정렬
data_result.sort_values(by='CCTV수', ascending = True)
# Out:
#         총인구수   남자인구수   여자인구수  여성비율  남성비율  CCTV수  2017년  2018년  2019년  \
# 구별
# 도봉구   333362  163051  170311    51    48   1356    134    223    214
# 종로구   151290   73746   77544    51    48   1729    259     85      9
# 중구    126171   61910   64261    50    49   2001    462    228    194
# 동작구   395963  191976  203987    51    48   2262    278    255    242
# 노원구   532905  257923  274982    51    48   2282    256    201    240
# 동대문구  346194  172113  174081    50    49   2315    136    197    209
# 금천구   232810  118209  114601    49    50   2365    196    540    369
# 용산구   228670  110356  118314    51    48   2383    351    125    307
# 마포구   374035  176891  197144    52    47   2401    358    340    384
# 강서구   591796  286563  305233    51    48   2437    506    259    457
# 강북구   313954  153235  160719    51    48   2462     34    385    976
# 강동구   436067  215335  220732    50    49   2547    273    377    356
# 광진구   351350  170262  181088    51    48   2556    675    465    712
# 송파구   675961  327164  348797    51    48   2743    241    542   1068
# 서대문구  309397  148663  160734    51    48   2939    415    246    328
# 중랑구   397015  196959  200056    50    49   3285    152    173   1050
# 양천구   458165  225186  232979    50    49   3307    120    142    255
# 성동구   300889  147273  153616    51    48   3515    790    409    262
# 은평구   480032  231528  248504    51    48   3660    403    635   1057
# 서초구   430826  206039  224787    52    47   3730   1061    436    361
# 성북구   442650  214437  228213    51    48   3754    461    860    716
# 영등포구  367678  182438  185240    50    49   3773    311    658     65
# 구로구   406664  200987  205677    50    49   4075    540    488    434
# 관악구   500094  251009  249085    49    50   4909    684    674    596
# 강남구   545169  260806  284363    52    47   6645   1004    744    796
#
#       2017년 이전       최근증가율
# 구별
# 도봉구        593   96.290051
# 종로구       1176   30.017007
# 중구         987   89.564336
# 동작구       1247   62.149158
# 노원구       1314   53.044140
# 동대문구      1669   32.474536
# 금천구        752  146.941489
# 용산구        983   79.654120
# 마포구       1079  100.278035
# 강서구        859  142.258440
# 강북구        581  240.103270
# 강동구        927  108.522114
# 광진구        529  350.094518
# 송파구        666  277.927928
# 서대문구      1512   65.410053
# 중랑구        980  140.306122
# 양천구       2592   19.945988
# 성동구       1598   91.426783
# 은평구       1277  164.056382
# 서초구       1432  129.748603
# 성북구       1484  137.264151
# 영등포구      1526   67.758847
# 구로구       2198   66.515014
# 관악구       2624   74.466463
# 강남구       3170   80.252366

# %% [markdown]
# ## 10. 서울시 자치구별 CCTV 현황 시각화

# %%
#한글폰트 깨짐 방지 코드
import matplotlib.pyplot as plt

import platform
'''
path = "c:/windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system... sorry~~~')


#코랩일 경우 위의 코드는 주석처리 아래의 코드로 실행
적용이 안되면 상단 런타임 메뉴에서 다시시작 및 모두실행으로 실행
그래도 안되면 런타임 메뉴에서 런타임 다시시작 -> 다시시작 및 모두실행

#한글 폰트 깨짐 방지 코드'''
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

#fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %% [markdown]
# ### 10-1. CCTV수가 가장 많은 구는 어디인가?

# %%
#'총계로' 막대 그래프 그리기 (kind='barh', grid=True, figsize=(10,10)
data_result['CCTV수'].plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
# '총계'로 소팅하여 막대 그래프 그리기 (kind='barh', grid=True, figsize=(10,10))
data_result['CCTV수'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 10-2. CCTV의 비율(인구수에 대비 CCTV 수)이 가장 높은 구는 어디인가?

# %%
# 'CCTV비율' 열 추가
data_result['CCTV비율'] = data_result['CCTV수'] / data_result['총인구수'] * 100
data_result.head()
# Out:
#        총인구수   남자인구수   여자인구수  여성비율  남성비율  CCTV수  2017년  2018년  2019년  2017년 이전  \
# 구별
# 종로구  151290   73746   77544    51    48   1729    259     85      9      1176
# 중구   126171   61910   64261    50    49   2001    462    228    194       987
# 용산구  228670  110356  118314    51    48   2383    351    125    307       983
# 성동구  300889  147273  153616    51    48   3515    790    409    262      1598
# 광진구  351350  170262  181088    51    48   2556    675    465    712       529
#
#           최근증가율    CCTV비율
# 구별
# 종로구   30.017007  1.142838
# 중구    89.564336  1.585943
# 용산구   79.654120  1.042113
# 성동구   91.426783  1.168205
# 광진구  350.094518   0.72748

# %%
# 소팅한 CCTV비율 막대 그래프 (kind='barh', grid=True, figsize=(10,10))
data_result['CCTV비율'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 10-3. 인구 수에 대한 CCTV수의 일반적인 분포를 살펴보자

# %%
plt.figure(figsize=(6,6))

# 인구수에 대한 CCTV 수 산점도 그래프 (kind='scatter', x='인구수', y='총계', s=50)

# %% [markdown]
# ### 10-4. 일반적인 기준에서 인구 수에 비해 CCTV 수가 많은 구와 적은 구는 어디인가?

# %%
# 데이터에 대한 대표선을 나타내는, 기울기, 절편을 fp1에 저장
data_result['총인구수'] = data_result['총인구수'].astype(float)
data_result['CCTV수'] = data_result['CCTV수'].astype(float)
fp1 = np.polyfit(data_result['총인구수'], data_result['CCTV수'], 1)
fp1
# Out:
# array([3.78940395e-03, 1.54253934e+03])

# %%
# 직선의 y값 생성시켜주는 함수
f1 = np.poly1d(fp1)
# 지정한 범위 내에서 데이터의 개수만큼 같은 간격의 숫자 생성, x축 숫자 생성
fx = np.linspace(100000, 700000, 100)

# %%
# 산점도 그래프 그리기
plt.figure(figsize=(9,9))
plt.scatter(data_result['총인구수'],data_result['CCTV수'], s=50)

# 선그래프 그리기, 순서대로, x축 데이터, y축 데이터, lw는 선 굵기
plt.plot(fx, f1(fx), '--', lw=2, color='g')

#점 옆에 구이름 텍스트 넣기
for n in range(25):
    plt.text(data_result['총인구수'][n]*1.02, data_result['CCTV수'][n]*0.98, data_result.index[n], fontsize=10)

plt.xlabel('총인구수')
plt.ylabel('CCTV수')
plt.grid()
plt.show()
